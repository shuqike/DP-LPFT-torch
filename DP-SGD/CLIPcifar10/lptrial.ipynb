# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy
# Out:
# Collecting git+https://github.com/awslabs/fast-differential-privacy
#   Cloning https://github.com/awslabs/fast-differential-privacy to /tmp/pip-req-build-ohay12th
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy /tmp/pip-req-build-ohay12th
#   Resolved https://github.com/awslabs/fast-differential-privacy to commit 1202baa441c38c338415bc24e4cf12514c46bac0
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fastDP
#   Building wheel for fastDP (setup.py) ... done
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101664 sha256=ac4f9579e44c7493c69b2087c442ff30247e7f87b6af084690b0434d488887c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7i3gay_g/wheels/b3/2b/b5/62668a08336b29e28ca790358738474aa8c2c68359b494f454
# Successfully built fastDP
# Installing collected packages: fastDP
# Successfully installed fastDP-1.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/CLIPcifar10/
# Out:
# /content/drive/Othercomputers/My Mac/CLIPcifar10

# %%
# !python linearprobing.py --name lptrial --seed 0 --epoch 20 --epsilon 1 --b 810 --lr 1 --g 0.9
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Total parameters 23528522. Trainable parameters 20490.
# Number of trainable components:  2 ; Number of trainable layers:  1
# >>>>>>>>>>>>>>>>> Applying  automatic  per-sample gradient clipping.
# >>>>>>>>>>>>>>>>> Block heads for per-sample gradient clipping are defined as: ['_model.fc']
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1359: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:129: UserWarning: Seems like `optimizer.step()` has been overridden after learning rate scheduler initialization. Please, make sure to call `optimizer.step()` before `lr_scheduler.step()`. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Seems like `optimizer.step()` has been overridden after learning rate scheduler "
# Accuracy of the network on the 10000 test images: 48 %, time spent per epoch 213.49322962760925
# Accuracy of the network on the 10000 test images: 46 %, time spent per epoch 212.98139905929565
# Accuracy of the network on the 10000 test images: 55 %, time spent per epoch 213.1220245361328

# %% [markdown]
# ### s0e50eps1.5b180lr0.001 SGD result
#
# 11 %
# ,11 %
# ,11 %
# ,11 %
# ,11 %
# ,12 %
# ,12 %
# ,12 %
# ,12 %
# ,12 %
# ,12 %
# ,12 %
# ,13 %
# ,13 %
# ,13 %
# ,13 %
# ,13 %
# ,13 %
# ,13 %
# ,13 %
# ,13 %
# ,14 %
# ,14 %
# ,14 %
# ,14 %
# ,14 %
# ,14 %
# ,14 %
# ,14 %
# ,14 %
# ,15 %
#
# ### s0e50eps1.5b180lr0.01 SGD result
#
# 11 %
# ,11 %
# ,12 %
# ,13 %
# ,14 %
# ,17 %
# ,19 %
# ,21 %
# ,23 %
# ,26 %
# ,28 %
# ,30 %
# ,31 %
# ,34 %
# ,36 %
# ,37 %
# ,38 %
# ,40 %
# ,41 %
# ,42 %
# ,44 %
# ,45 %
# ,47 %
# ,48 %
# ,49 %
# ,50 %
# ,50 %
#
# ### s0e50eps1.5b180lr0.1 SGD result
#
# 32 %
# ,45 %
# ,51 %
# ,56 %
# ,59 %
# ,59 %
# ,58 %
# ,55 %
# ,56 %
# ,57 %
# ,57 %
#
# ### s0e50eps1.5b180lr1 SGD result
#
# 37 %
# ,49 %
# ,52 %
# ,60 %
# ,59 %
# ,60 %
# ,60 %
#
# ### s0e50eps1.5b180lr1g0.9 SGD result
#
# 44 %
# ,51 %
# ,53 %
# ,58 %
# ,58 %
# ,60 %
# ,60 %
# ,59 %
# ,61 %
# ,60 %
# ,60 %
# ,61 %
# ,60 %
# ,61 %
# ,61 %
# ,61 %
# ,61 %
# ,60 %
# ,60 %
# ,60 %
# ,61 %
# ,61 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,61 %
# ,61 %
# ,61 %
# ,61 %
# ,61 %
# ,61 %
# ,61 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
# ,60 %
