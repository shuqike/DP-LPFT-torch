# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy
# %pip install opacus torchinfo
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy to /tmp/pip-req-build-2f62x5x9
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy /tmp/pip-req-build-2f62x5x9
#   Resolved https://github.com/awslabs/fast-differential-privacy to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=6e26d53fe3ee54e1188a402afb554b0ffc7390d1da8c7f9b1109dda958de3b4e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fwr5j4wu/wheels/b3/2b/b5/62668a08336b29e28ca790358738474aa8c2c68359b494f454
# Successfully built fastDP
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
# %cd /content/drive/Othercomputers/My Mac/MOCOcifar10/

# %%
python main.py --device cuda:1 --seed 0 --epoch 30 --lp-epoch 0 --lplr 0 --ftlr 0.001

# %%
python main.py --device cuda:1 --seed 0 --epoch 30 --lp-epoch 0 --lplr 0 --ftlr 0.0005
