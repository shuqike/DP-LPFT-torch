# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy
# %pip install opacus torchinfo

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/Othercomputers/My Mac/MOCOcifar10/

# %% [markdown]
# !python main.py --seed 0 --epoch 30 --lp-epoch 30 --lplr 0 --ftlr 0.001
#
# without scheduler
#
# 8.47 361.85496187210083
#
# 8.33 361.77938175201416
#
# 9.72 361.75395250320435
#
# 9.94 361.68192768096924
#
# 10.43 361.59224557876587
#
# 9.16 361.5903491973877
#
# 10.65 361.4822506904602
#
# 11.49 361.4372181892395
#
# 9.99 361.4116053581238
#
# 9.9 361.39478516578674
#
# 11.17 361.3307731151581
#
# 11.01 361.2881586551666
#
# 14.16 361.26611280441284
#
# 12.43 361.22339129447937
#
# 11.64 361.1876106262207
#
# 9.94 361.1675138473511
#
# 11.13 361.09862422943115
#
# 12.55 361.04363465309143
#
# 9.57 361.04630160331726
#
# 11.84 360.9874792098999
#
# 12.03 360.9504041671753
#
# 15.14 360.9549593925476
#
# 13.74 360.8504660129547
#
# 11.71 360.84295678138733
#
# 12.94 360.7564435005188
#
# 15.22 360.7142632007599
#
# 15.81 360.7003753185272
#
# 12.14 360.6840081214905
#
# 15.22 360.60784006118774
#
# 12.96 360.56615376472473

# %% [markdown]
# !python main.py --seed 0 --epoch 20 --lp-epoch 0 --lplr 0 --ftlr 0.05
#
# 9.97 361.73879766464233
#
# 11.75 361.97321677207947
#
# 15.42 365.2513430118561
#
# 10.16 359.5553069114685
#
# 13.69 354.3015522956848
#
# 19.48 345.11729550361633
#
# 24.42 339.4377739429474
#
# 17.45 335.87140810489655
#
# 22.31 328.00911271572113
#
# 25.21 321.2203691005707
#
# 25.42 317.23735547065735
#
# 24.83 319.60041892528534
#
# 28.21 310.9297659397125
#
# 28.72 310.06167244911194
#
# 30.1 308.5761008262634
#
# 28.38 308.7637153863907
#
# 27.12 306.121133685112
#
# 29.97 303.13213884830475
#
# 29.76 300.60579097270966
#
# 30.3 303.8238923549652

# %%
# !python main.py --seed 0 --epoch 20 --lp-epoch 0 --lplr 0 --ftlr 0.05 --scheduler
