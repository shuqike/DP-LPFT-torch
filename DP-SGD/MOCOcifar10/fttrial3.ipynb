# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy
# %pip install opacus torchinfo
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy to /tmp/pip-req-build-0_kvkso8
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy /tmp/pip-req-build-0_kvkso8
#   Resolved https://github.com/awslabs/fast-differential-privacy to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=0ea793f0a7d380b0321a794b7877c9ec1eaa418478b3f55f35c519394844e043
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rx66e3t4/wheels/b3/2b/b5/62668a08336b29e28ca790358738474aa8c2c68359b494f454
# Successfully built fastDP
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/MOCOcifar10/
# Out:
# /content/drive/Othercomputers/My Mac/MOCOcifar10

# %%
# !python main.py --seed 0 --epoch 30 --lp-epoch 0 --lplr 0 --ftlr 0.001
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Total parameters 23528522. Trainable parameters 20490.
# Number of trainable components:  2 ; Number of trainable layers:  1
# >>>>>>>>>>>>>>>>> Applying  automatic  per-sample gradient clipping.
# >>>>>>>>>>>>>>>>> Block heads for per-sample gradient clipping are defined as: ['_model.fc']
# Number of trainable components:  161 ; Number of trainable layers:  107
# >>>>>>>>>>>>>>>>> Applying  automatic  per-sample gradient clipping.
# >>>>>>>>>>>>>>>>> Block heads for per-sample gradient clipping are defined as: ['_model.conv1']
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1359: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# ...

# %%
# !python main.py --seed 0 --epoch 30 --lp-epoch 0 --lplr 0 --ftlr 0.0005
