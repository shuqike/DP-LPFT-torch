# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy to /tmp/pip-req-build-w1yb71v0
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy /tmp/pip-req-build-w1yb71v0
#   Resolved https://github.com/awslabs/fast-differential-privacy to commit 1202baa441c38c338415bc24e4cf12514c46bac0
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101664 sha256=766d669462a6af97e377ae7db2a120d23f2096cc84d313f6ec1beb8f312f98ad
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_dnq88pg/wheels/b3/2b/b5/62668a08336b29e28ca790358738474aa8c2c68359b494f454
# Successfully built fastDP
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/NormaLcifar10/
# Out:
# /content/drive/Othercomputers/My Mac/NormaLcifar10

# %%
# !python linearprobing.py --name fttrial --seed 0 --epoch 50 --epsilon 1 --b 810 --lr 1 --g 0.8
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 135MB/s]
# Total parameters 11689512. Trainable parameters 513000.
# Number of trainable components:  2 ; Number of trainable layers:  1
# >>>>>>>>>>>>>>>>> Applying  automatic  per-sample gradient clipping.
# >>>>>>>>>>>>>>>>> Block heads for per-sample gradient clipping are defined as: ['fc']
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1359: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# ...

# %% [markdown]
# !python linearprobing.py --name lptrial --seed 0 --epoch 50 --epsilon 1.5 --b 810 --lr 1 --g 0.9
#
# 61 %,69 %,72 %,74 %,74 %,75 %,75 %,76 %,76 %,76 %,76 %,76 %,76 %,76 %
#
# !python linearprobing.py --name lptrial --seed 0 --epoch 50 --epsilon 1 --b 810 --lr 1 --g 0.9
#
# 60 %,68 %,71 %,73 %,74 %,74 %,75 %,75 %,76 %,76 %,76 %,76 %,76 %,76 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %,77 %
#
# !python linearprobing.py --name fttrial --seed 0 --epoch 50 --epsilon 1 --b 810 --lr 1 --g 0.8
#
# 59 %,68 %,70 %,72 %,72 %,73 %,74 %,74 %,74 %,74 %,74 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %,75 %
