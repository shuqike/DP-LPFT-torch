# %%
# %pip install opacus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/NormaLcifar10/
# Out:
# /content/drive/Othercomputers/My Mac/NormaLcifar10

# %% [markdown]
# !python lpft.py --name lpft2.1 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 10 --b 64 --lplr 0.7 --ftlr 0.001
#
# Accuracy of the network on the 10000 test images: 11 %, privacy cost0.17142715263682495
#
# Accuracy of the network on the 10000 test images: 23 %, privacy cost0.23648795089642927
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.2877168274286489
#
# Accuracy of the network on the 10000 test images: 22 %, privacy cost0.33163745603046507
#
# Accuracy of the network on the 10000 test images: 26 %, privacy cost0.3708228612279802
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.4066081048903203
#
# Accuracy of the network on the 10000 test images: 28 %, privacy cost0.43979500305607827
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.4709103936630069
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.5003225110500548
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.5283013427540609
#
# Accuracy of the network on the 10000 test images: 36 %, privacy cost0.555051764667509
#
# Accuracy of the network on the 10000 test images: 36 %, privacy cost0.5807334096839215
#
# Accuracy of the network on the 10000 test images: 36 %, privacy cost0.6054742935098354
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.6293784129347479
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.65253146626167
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.6750058406477014
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.6968624759916243
#
# Accuracy of the network on the 10000 test images: 39 %, privacy cost0.7181538191222063
#
# Accuracy of the network on the 10000 test images: 39 %, privacy cost0.7389253708668476
#
# Accuracy of the network on the 10000 test images: 40 %, privacy cost0.7592164673826062

# %% [markdown]
# !python lpft.py --name lpft2.2 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 10 --b 64 --lplr 0.7 --ftlr 0.0001
#
# Accuracy of the network on the 10000 test images: 18 %, privacy cost0.17142715263682495
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.23648795089642927
#
# Accuracy of the network on the 10000 test images: 21 %, privacy cost0.2877168274286489
#
# Accuracy of the network on the 10000 test images: 25 %, privacy cost0.33163745603046507
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.3708228612279802
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.4066081048903203
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.43979500305607827
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.4709103936630069
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.5003225110500548
#
# Accuracy of the network on the 10000 test images: 28 %, privacy cost0.5283013427540609
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.555051764667509
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.5807334096839215
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.6054742935098354
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.6293784129347479
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.65253146626167
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.6750058406477014
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.6968624759916243
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.7181538191222063
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.7389253708668476
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.7592164673826062

# %% [markdown]
# !python lpft.py --name lpft2.3 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 10 --b 64 --lplr 0.7 --ftlr 0.00001
#
# Accuracy of the network on the 10000 test images: 17 %, privacy cost0.17142715263682495
#
# Accuracy of the network on the 10000 test images: 19 %, privacy cost0.23648795089642927
#
# Accuracy of the network on the 10000 test images: 27 %, privacy cost0.2877168274286489
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.33163745603046507
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.3708228612279802
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.4066081048903203
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.43979500305607827
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.4709103936630069
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.5003225110500548
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.5283013427540609
#
# Accuracy of the network on the 10000 test images: 33 %, privacy cost0.555051764667509
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.5807334096839215
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.6054742935098354
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.6293784129347479
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.65253146626167
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.6750058406477014
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.6968624759916243
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.7181538191222063
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.7389253708668476
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.7592164673826062

# %% [markdown]
# !python lpft.py --name lpft2.4 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 15 --b 64 --lplr 0.7 --ftlr 0.001
#
# Accuracy of the network on the 10000 test images: 16 %, privacy cost0.17142715263682495
#
# Accuracy of the network on the 10000 test images: 20 %, privacy cost0.23648795089642927
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.2877168274286489
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.33163745603046507
#
# Accuracy of the network on the 10000 test images: 28 %, privacy cost0.3708228612279802
#
# Accuracy of the network on the 10000 test images: 27 %, privacy cost0.4066081048903203
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.43979500305607827
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.4709103936630069
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.5003225110500548
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.5283013427540609
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.555051764667509
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.5807334096839215
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.6054742935098354
#
# Accuracy of the network on the 10000 test images: 36 %, privacy cost0.6293784129347479
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.65253146626167
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.6750058406477014
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.6968624759916243
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.7181538191222063
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.7389253708668476
#
# Accuracy of the network on the 10000 test images: 39 %, privacy cost0.7592164673826062

# %% [markdown]
# !python lpft.py --name lpft2.5 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 15 --b 64 --lplr 0.7 --ftlr 0.0001
#
# Accuracy of the network on the 10000 test images: 15 %, privacy cost0.1714271525080231
#
# Accuracy of the network on the 10000 test images: 23 %, privacy cost0.2364879509541473
#
# Accuracy of the network on the 10000 test images: 18 %, privacy cost0.28771682744995936
#
# Accuracy of the network on the 10000 test images: 22 %, privacy cost0.33163745605066686
#
# Accuracy of the network on the 10000 test images: 23 %, privacy cost0.37082286087436145
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.40660810398536673
#
# Accuracy of the network on the 10000 test images: 26 %, privacy cost0.4397950024218613
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.4709103958088995
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.500322511921282
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.5283013400740065
#
# Accuracy of the network on the 10000 test images: 33 %, privacy cost0.5550517645014527
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.580733409194068
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.6054742929980161
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.629378407183522
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.6525314677953297
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.6750058421288592
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.6968624722836431
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.7181538233180911
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.7389253606330978
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.7592164757509948

# %% [markdown]
# !python lpft.py --name lpft2.6 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 15 --b 64 --lplr 0.7 --ftlr 0.00001
#
# Accuracy of the network on the 10000 test images: 19 %, privacy cost0.1714271525080231
#
# Accuracy of the network on the 10000 test images: 19 %, privacy cost0.2364879509541473
#
# Accuracy of the network on the 10000 test images: 22 %, privacy cost0.28771682744995936
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.33163745605066686
#
# Accuracy of the network on the 10000 test images: 25 %, privacy cost0.37082286087436145
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.40660810398536673
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.4397950024218613
#
# Accuracy of the network on the 10000 test images: 32 %, privacy cost0.4709103958088995
#
# Accuracy of the network on the 10000 test images: 33 %, privacy cost0.500322511921282
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.5283013400740065
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.5550517645014527
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.580733409194068
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.6054742929980161
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.629378407183522
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.6525314677953297
#
# Accuracy of the network on the 10000 test images: 37 %, privacy cost0.6750058421288592
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.6968624722836431
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.7181538233180911
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.7389253606330978
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.7592164757509948

# %% [markdown]
# !python lpft.py --name lpft2.7 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 15 --b 64 --lplr 0.7 --ftlr 0.01
#
# Accuracy of the network on the 10000 test images: 13 %, privacy cost0.1714271525080231
#
# Accuracy of the network on the 10000 test images: 21 %, privacy cost0.2364879509541473
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.28771682744995936
#
# Accuracy of the network on the 10000 test images: 25 %, privacy cost0.33163745605066686
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.37082286087436145
#
# Accuracy of the network on the 10000 test images: 27 %, privacy cost0.40660810398536673
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.4397950024218613
#
# Accuracy of the network on the 10000 test images: 28 %, privacy cost0.4709103958088995
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.500322511921282
#
# Accuracy of the network on the 10000 test images: 29 %, privacy cost0.5283013400740065
#
# Accuracy of the network on the 10000 test images: 31 %, privacy cost0.5550517645014527
#
# Accuracy of the network on the 10000 test images: 30 %, privacy cost0.580733409194068
#
# Accuracy of the network on the 10000 test images: 33 %, privacy cost0.6054742929980161
#
# Accuracy of the network on the 10000 test images: 33 %, privacy cost0.629378407183522
#
# Accuracy of the network on the 10000 test images: 34 %, privacy cost0.6525314677953297
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.6750058421288592
#
# Accuracy of the network on the 10000 test images: 40 %, privacy cost0.6968624722836431
#
# Accuracy of the network on the 10000 test images: 42 %, privacy cost0.7181538233180911
#
# Accuracy of the network on the 10000 test images: 42 %, privacy cost0.7389253606330978
#
# Accuracy of the network on the 10000 test images: 43 %, privacy cost0.7592164757509948

# %% [markdown]
# !python lpft.py --name lpft2.8 --seed 0 --epoch 20 --noise-multiplier 1 --lp-epoch 5 --b 64 --lplr 0.8 --ftlr 0.01
#
# Accuracy of the network on the 10000 test images: 13 %, privacy cost0.1714271525080231
#
# Accuracy of the network on the 10000 test images: 16 %, privacy cost0.2364879509541473
#
# Accuracy of the network on the 10000 test images: 26 %, privacy cost0.28771682744995936
#
# Accuracy of the network on the 10000 test images: 24 %, privacy cost0.33163745605066686
#
# Accuracy of the network on the 10000 test images: 25 %, privacy cost0.37082286087436145
#
# Accuracy of the network on the 10000 test images: 35 %, privacy cost0.40660810398536673
#
# Accuracy of the network on the 10000 test images: 38 %, privacy cost0.4397950024218613
#
# Accuracy of the network on the 10000 test images: 39 %, privacy cost0.4709103958088995
#
# Accuracy of the network on the 10000 test images: 40 %, privacy cost0.500322511921282
#
# Accuracy of the network on the 10000 test images: 41 %, privacy cost0.5283013400740065
#
# Accuracy of the network on the 10000 test images: 42 %, privacy cost0.5550517645014527
#
# Accuracy of the network on the 10000 test images: 42 %, privacy cost0.580733409194068
#
# Accuracy of the network on the 10000 test images: 43 %, privacy cost0.6054742929980161
#
# Accuracy of the network on the 10000 test images: 44 %, privacy cost0.629378407183522
#
# Accuracy of the network on the 10000 test images: 46 %, privacy cost0.6525314677953297
#
# Accuracy of the network on the 10000 test images: 46 %, privacy cost0.6750058421288592
#
# Accuracy of the network on the 10000 test images: 46 %, privacy cost0.6968624722836431
#
# Accuracy of the network on the 10000 test images: 46 %, privacy cost0.7181538233180911
#
# Accuracy of the network on the 10000 test images: 46 %, privacy cost0.7389253606330978
#
# Accuracy of the network on the 10000 test images: 47 %, privacy cost0.7592164757509948
